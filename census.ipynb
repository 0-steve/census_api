# %%
import pandas as pd
import numpy as np
import requests
from functools import lru_cache
import hashlib

# %%
pd.options.mode.chained_assignment = None

# %%
k = "f7217cc1222e7cecb49db88b036d517681dd703b"

# %%
@lru_cache(maxsize=None)
def census_tract_api(year, profile, state_id, k):
    url = f"https://api.census.gov/data/{year}/acs/acs5/profile?get=group({profile})&for=tract:*&in=state:{state_id}&key={k}"

    # request url for provided variable code & year
    get_response = requests.get(url)

    # convert api return as into json
    json_return = get_response.json()

    # convert json to pandas data frame
    df_tract = pd.DataFrame(json_return)  
    
    return df_tract

# %%
@lru_cache(maxsize=None)
def census_var_names(var):
    url = f"https://api.census.gov/data/2020/acs/acs5/profile/variables/{var}.json"
    
    # request url for provided variable code
    get_response = requests.get(url) 

    # convert api return as into json
    json_return = get_response.json()

    # extract the value for "label" 
    var_label = json_return["label"]

    return var_label

def apply_var_cols(df):
    # transpose first row containing all variable codes
    df_vars = df.iloc[:1, :].T.rename(columns={0:"variable"})

    # columns to keep
    col_keep = list(df_vars.variable[-5:])

    # iterate through each variable code and get the return api label
    var_labels = [ census_var_names(var) for var in df_vars.variable[:-5] ]

    # combine columns
    new_cols = var_labels + col_keep

    # apply column names
    df.columns = new_cols

    return df

# %%
# call census api using function
df_api_return = census_tract_api(2020, "DP02", "19", k)

# %%
# df_api_return.head()

# %%
df_census = apply_var_cols(df_api_return)

# %%
df_census.head()
# Out:
#   Estimate!!HOUSEHOLDS BY TYPE!!Total households  \
# 0                                     DP02_0001E
# 1                                           1891
# 2                                           1192
# 3                                           1587
# 4                                           1339
#
#   Annotation of Estimate!!HOUSEHOLDS BY TYPE!!Total households  \
# 0                                        DP02_0001EA
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   Margin of Error!!HOUSEHOLDS BY TYPE!!Total households  \
# 0                                         DP02_0001M
# 1                                                160
# 2                                                197
# 3                                                161
# 4                                                149
#
#   Annotation of Margin of Error!!HOUSEHOLDS BY TYPE!!Total households  \
# 0                                        DP02_0001MA
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   Percent!!HOUSEHOLDS BY TYPE!!Total households  \
# 0                                   DP02_0001PE
# 1                                          1891
# 2                                          1192
# 3                                          1587
# 4                                          1339
#
#   Annotation of Percent!!HOUSEHOLDS BY TYPE!!Total households  \
# 0                                       DP02_0001PEA
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households  \
# 0                                        DP02_0001PM
# 1                                         -888888888
# 2                                         -888888888
# 3                                         -888888888
# 4                                         -888888888
#
#   Annotation of Percent Margin of Error!!HOUSEHOLDS BY TYPE!!Total households  \
# 0                                       DP02_0001PMA
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#   Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Married-couple household  \
# 0                                         DP02_0002E
# 1                                               1232
# 2                                                824
# 3                                               1021
# 4                                                703
#
#   Annotation of Estimate!!HOUSEHOLDS BY TYPE!!Total households!!Married-couple household  \
# 0                                        DP02_0002EA
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Annotation of Margin of Error!!COMPUTERS AND INTERNET USE!!Total households!!With a broadband Internet subscription  \
# 0                                        DP02_0154MA
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   Percent!!COMPUTERS AND INTERNET USE!!Total households!!With a broadband Internet subscription  \
# 0                                        DP02_0154PE
# 1                                               88.9
# 2                                               78.4
# 3                                               86.1
# 4                                               82.2
#
#   Annotation of Percent!!COMPUTERS AND INTERNET USE!!Total households!!With a broadband Internet subscription  \
# 0                                       DP02_0154PEA
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#   Percent Margin of Error!!COMPUTERS AND INTERNET USE!!Total households!!With a broadband Internet subscription  \
# 0                                        DP02_0154PM
# 1                                                4.6
# 2                                                8.0
# 3                                                5.4
# 4                                                6.0
#
#   Annotation of Percent Margin of Error!!COMPUTERS AND INTERNET USE!!Total households!!With a broadband Internet subscription  \
# 0                                       DP02_0154PMA
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                  GEO_ID                                             NAME  \
# 0                GEO_ID                                             NAME
# 1  1400000US19155031601  Census Tract 316.01, Pottawattamie County, Iowa
# 2  1400000US19155031602  Census Tract 316.02, Pottawattamie County, Iowa
# 3  1400000US19155031700     Census Tract 317, Pottawattamie County, Iowa
# 4  1400000US19155031800     Census Tract 318, Pottawattamie County, Iowa
#
#    state  county   tract
# 0  state  county   tract
# 1     19     155  031601
# 2     19     155  031602
# 3     19     155  031700
# 4     19     155  031800
#
# [5 rows x 1237 columns]

# %%
df_variable_codes = df_census.iloc[:1, :-5].T.reset_index().rename({"index": "variable", 0: "code"}, axis = 1)

df_variable_codes = df_variable_codes[["code", "variable"]]

measurement = []
demographic_target = []
demographic = []

for var in df_variable_codes.variable:
    var_split = var.split("!!")

    if len(var_split) == 0:
        continue

    col_measure = var_split[0]

    measurement.append(col_measure.lower()) # measurement value
    demographic_target.append(var_split[1].lower()) # demographic target
    
    if len(var_split[2:]) > 1:
        demographic.append(" ".join(map(str, var_split[2:])).lower()) # demographic
    else: 
        demographic.append(var_split[2].lower()) # demographic

df_variable_codes["measurement"] = measurement
df_variable_codes["demographic_target"] = demographic_target
df_variable_codes["demographic"] = demographic

# %%
df_variable_codes.head()
# Out:
#           code                                           variable  \
# 0   DP02_0001E     Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 1  DP02_0001EA  Annotation of Estimate!!HOUSEHOLDS BY TYPE!!To...
# 2   DP02_0001M  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 3  DP02_0001MA  Annotation of Margin of Error!!HOUSEHOLDS BY T...
# 4  DP02_0001PE      Percent!!HOUSEHOLDS BY TYPE!!Total households
#
#                      measurement  demographic_target       demographic
# 0                       estimate  households by type  total households
# 1         annotation of estimate  households by type  total households
# 2                margin of error  households by type  total households
# 3  annotation of margin of error  households by type  total households
# 4                        percent  households by type  total households

# %%
# replace header with first row
df_census.columns = df_census.iloc[0]

df_census = df_census[1:]

# re order headers
df_census = df_census[ df_census.columns.tolist()[-5:] + df_census.columns.tolist()[:-5] ]

# %%
# create geo table

df_census_geo = df_census.iloc[:, :5]

df_census_geo.head()
# Out:
# 0                GEO_ID                                             NAME  \
# 1  1400000US19155031601  Census Tract 316.01, Pottawattamie County, Iowa
# 2  1400000US19155031602  Census Tract 316.02, Pottawattamie County, Iowa
# 3  1400000US19155031700     Census Tract 317, Pottawattamie County, Iowa
# 4  1400000US19155031800     Census Tract 318, Pottawattamie County, Iowa
# 5  1400000US19155031900     Census Tract 319, Pottawattamie County, Iowa
#
# 0 state county   tract
# 1    19    155  031601
# 2    19    155  031602
# 3    19    155  031700
# 4    19    155  031800
# 5    19    155  031900

# %%
# create demographic target ids

demographic_target_ids = [ hashlib.md5(demo_target.encode("utf-8")).hexdigest() for demo_target in df_variable_codes.demographic_target ]

df_variable_codes["demographic_target_id"] = demographic_target_ids

# %%
# create id for every demographic in a demographic target
demographic_ids = []
for demo_target, demo in zip(df_variable_codes["demographic_target"], df_variable_codes["demographic"]):
    demo_demo_target = demo_target + " " + demo
    demographic_id = hashlib.md5(demo_demo_target.encode("utf-8")).hexdigest()
    demographic_ids.append(demographic_id)

df_variable_codes["demographic_id"] = demographic_ids

# %%
df_variable_codes.head()
# Out:
#           code                                           variable  \
# 0   DP02_0001E     Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 1  DP02_0001EA  Annotation of Estimate!!HOUSEHOLDS BY TYPE!!To...
# 2   DP02_0001M  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 3  DP02_0001MA  Annotation of Margin of Error!!HOUSEHOLDS BY T...
# 4  DP02_0001PE      Percent!!HOUSEHOLDS BY TYPE!!Total households
#
#                      measurement  demographic_target       demographic  \
# 0                       estimate  households by type  total households
# 1         annotation of estimate  households by type  total households
# 2                margin of error  households by type  total households
# 3  annotation of margin of error  households by type  total households
# 4                        percent  households by type  total households
#
#               demographic_target_id                    demographic_id
# 0  43551e2203882bcfa813b5a1f84408c3  44e920fd50fbc189b315aa67243c13f8
# 1  43551e2203882bcfa813b5a1f84408c3  44e920fd50fbc189b315aa67243c13f8
# 2  43551e2203882bcfa813b5a1f84408c3  44e920fd50fbc189b315aa67243c13f8
# 3  43551e2203882bcfa813b5a1f84408c3  44e920fd50fbc189b315aa67243c13f8
# 4  43551e2203882bcfa813b5a1f84408c3  44e920fd50fbc189b315aa67243c13f8

# %%
# create dataframe for each demographic target

# break out demographic target by id
demo_target_df_dict = {demo_target: df_variable_codes[df_variable_codes["demographic_target_id"] == demo_target] for demo_target in df_variable_codes.demographic_target_id.unique()}

# append geo id to each demographic target
demo_target_geo_df_dict = dict()

for demo_target_id, demo_target_df in demo_target_df_dict.items():
    demo_target_codes = demo_target_df.code.unique().tolist()
    demo_target_geo_df_dict[demo_target_id] = df_census[ [df_census_geo.columns[0]] + demo_target_codes ]

# %%
# demo_target_test = demo_target_df_dict["43551e2203882bcfa813b5a1f84408c3"]

# demo_target_test = demo_target_test[demo_target_test["measurement"] == "estimate"]

# demo_target_test

# break out demographic target by measurement
measurement_df_dict = {measurement: df_variable_codes[df_variable_codes["measurement"] == measurement] for measurement in df_variable_codes.measurement.unique()}

# append geo id to each measurement
measurement_geo_df_dict = dict()

for measurement, measurement_df in measurement_df_dict.items():
    variable_codes = measurement_df.code.unique().tolist()
    measurement_geo_df_dict[measurement] = df_census[ [df_census_geo.columns[0]] + variable_codes ]

# %%
estimate_variables = measurement_df_dict["estimate"]
estimate_anotations = measurement_df_dict["annotation of estimate"]
margin_of_errore_variables = measurement_df_dict["margin of error"]
margin_of_error_annotation = measurement_df_dict["annotation of margin of error"]
percent_variables = measurement_df_dict["percent"]
percent_annotations = measurement_df_dict["annotation of percent"]
percent_margin_of_error_variables = measurement_df_dict["percent margin of error"]
percent_margin_of_error_annotations = measurement_df_dict["annotation of percent margin of error"]

estimate_variables
# Out:
#             code                                           variable  \
# 0     DP02_0001E     Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 8     DP02_0002E  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 16    DP02_0003E  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 24    DP02_0004E  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 32    DP02_0005E  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# ...          ...                                                ...
# 1192  DP02_0150E        Estimate!!ANCESTRY!!Total population!!Welsh
# 1200  DP02_0151E  Estimate!!ANCESTRY!!Total population!!West Ind...
# 1208  DP02_0152E  Estimate!!COMPUTERS AND INTERNET USE!!Total ho...
# 1216  DP02_0153E  Estimate!!COMPUTERS AND INTERNET USE!!Total ho...
# 1224  DP02_0154E  Estimate!!COMPUTERS AND INTERNET USE!!Total ho...
#
#      measurement          demographic_target  \
# 0       estimate          households by type
# 8       estimate          households by type
# 16      estimate          households by type
# 24      estimate          households by type
# 32      estimate          households by type
# ...          ...                         ...
# 1192    estimate                    ancestry
# 1200    estimate                    ancestry
# 1208    estimate  computers and internet use
# 1216    estimate  computers and internet use
# 1224    estimate  computers and internet use
#
#                                             demographic  \
# 0                                      total households
# 8             total households married-couple household
# 16    total households married-couple household with...
# 24         total households cohabiting couple household
# 32    total households cohabiting couple household w...
# ...                                                 ...
# 1192                             total population welsh
# 1200  total population west indian (excluding hispan...
# 1208                                   total households
# 1216                   total households with a computer
# 1224  total households with a broadband internet sub...
#
#                  demographic_target_id                    demographic_id
# 0     43551e2203882bcfa813b5a1f84408c3  44e920fd50fbc189b315aa67243c13f8
# 8     43551e2203882bcfa813b5a1f84408c3  729132cbd2d86abb56276288c1fa7689
# 16    43551e2203882bcfa813b5a1f84408c3  49dd32656aec4e3e107ed6cb07b7e1a7
# 24    43551e2203882bcfa813b5a1f84408c3  ab9838ecf4da5ffc6a7e87823da3cfc5
# 32    43551e2203882bcfa813b5a1f84408c3  828e831e49e496641fc8711765c58e38
# ...                                ...                               ...
# 1192  fcec51e8d355c65c71c8e4ebce8699bb  cd51c946f47fbafd9ed9e5a6695d68df
# 1200  fcec51e8d355c65c71c8e4ebce8699bb  db29291bc95ddc5a4c5129ea22147ef6
# 1208  bceb3c1f81e05c551b04247cbbf4998e  e589eadf35554fe19e286d6f44ccddd1
# 1216  bceb3c1f81e05c551b04247cbbf4998e  76e578c8c1b6f25ae4b11331c19834ab
# 1224  bceb3c1f81e05c551b04247cbbf4998e  2c8ba9d62282dd5f4a52a3e39244e6b6
#
# [154 rows x 7 columns]

# %%
measurement_geo_df_dict["estimate"]
# Out:
# 0                  GEO_ID DP02_0001E DP02_0002E  DP02_0003E DP02_0004E  \
# 1    1400000US19155031601       1891       1232  -888888888        132
# 2    1400000US19155031602       1192        824  -888888888         45
# 3    1400000US19155031700       1587       1021  -888888888         85
# 4    1400000US19155031800       1339        703  -888888888         13
# 5    1400000US19155031900       1372        843  -888888888        122
# ..                    ...        ...        ...         ...        ...
# 892  1400000US19155030900        941         78  -888888888         60
# 893  1400000US19155031000        935        367  -888888888        100
# 894  1400000US19155031100       1084        405  -888888888         74
# 895  1400000US19155031200       1314        560  -888888888         49
# 896  1400000US19155031300       1257        335  -888888888        186
#
# 0    DP02_0005E DP02_0006E  DP02_0007E DP02_0008E DP02_0009E  ... DP02_0145E  \
# 1    -888888888        189  -888888888        146         90  ...          0
# 2    -888888888         99  -888888888         61         43  ...          0
# 3    -888888888        144  -888888888         87         24  ...          0
# 4    -888888888        276  -888888888        228         58  ...          0
# 5    -888888888        112  -888888888         91         19  ...          0
# ..          ...        ...         ...        ...        ...  ...        ...
# 892  -888888888        349  -888888888        328         95  ...          0
# 893  -888888888        166  -888888888         92         38  ...          0
# 894  -888888888        314  -888888888        258         59  ...          0
# 895  -888888888        212  -888888888        180         69  ...          0
# 896  -888888888        324  -888888888        269        118  ...          0
#
# 0   DP02_0146E DP02_0147E DP02_0148E DP02_0149E DP02_0150E DP02_0151E  \
# 1            0         85          7          0         21          0
# 2            9         88          0          0         36          0
# 3           55        124         22          0          0          0
# 4            0         26         11          0         25          0
# 5            0        103          0          0         14          0
# ..         ...        ...        ...        ...        ...        ...
# 892          0         13          0          0          9          0
# 893          0         26          5          0         45          0
# 894          0         61          0          0         25          0
# 895         11        108         17          0          0          0
# 896          0         52          0          0         14          0
#
# 0   DP02_0152E DP02_0153E DP02_0154E
# 1         1891       1737       1681
# 2         1192       1075        934
# 3         1587       1455       1367
# 4         1339       1200       1100
# 5         1372       1308       1236
# ..         ...        ...        ...
# 892        941        678        494
# 893        935        824        740
# 894       1084       1049        903
# 895       1314       1239       1179
# 896       1257       1085        992
#
# [896 rows x 155 columns]

# %%
df_census_geo
# Out:
# 0                  GEO_ID                                             NAME  \
# 1    1400000US19155031601  Census Tract 316.01, Pottawattamie County, Iowa
# 2    1400000US19155031602  Census Tract 316.02, Pottawattamie County, Iowa
# 3    1400000US19155031700     Census Tract 317, Pottawattamie County, Iowa
# 4    1400000US19155031800     Census Tract 318, Pottawattamie County, Iowa
# 5    1400000US19155031900     Census Tract 319, Pottawattamie County, Iowa
# ..                    ...                                              ...
# 892  1400000US19155030900     Census Tract 309, Pottawattamie County, Iowa
# 893  1400000US19155031000     Census Tract 310, Pottawattamie County, Iowa
# 894  1400000US19155031100     Census Tract 311, Pottawattamie County, Iowa
# 895  1400000US19155031200     Census Tract 312, Pottawattamie County, Iowa
# 896  1400000US19155031300     Census Tract 313, Pottawattamie County, Iowa
#
# 0   state county   tract
# 1      19    155  031601
# 2      19    155  031602
# 3      19    155  031700
# 4      19    155  031800
# 5      19    155  031900
# ..    ...    ...     ...
# 892    19    155  030900
# 893    19    155  031000
# 894    19    155  031100
# 895    19    155  031200
# 896    19    155  031300
#
# [896 rows x 5 columns]

# %%
demo_target_geo_df_dict["43551e2203882bcfa813b5a1f84408c3"]
# Out:
# 0                  GEO_ID DP02_0001E DP02_0001EA DP02_0001M DP02_0001MA  \
# 1    1400000US19155031601       1891        None        160        None
# 2    1400000US19155031602       1192        None        197        None
# 3    1400000US19155031700       1587        None        161        None
# 4    1400000US19155031800       1339        None        149        None
# 5    1400000US19155031900       1372        None        117        None
# ..                    ...        ...         ...        ...         ...
# 892  1400000US19155030900        941        None        143        None
# 893  1400000US19155031000        935        None        108        None
# 894  1400000US19155031100       1084        None        177        None
# 895  1400000US19155031200       1314        None        114        None
# 896  1400000US19155031300       1257        None        224        None
#
# 0   DP02_0001PE DP02_0001PEA DP02_0001PM DP02_0001PMA DP02_0002E  ...  \
# 1          1891         None  -888888888          (X)       1232  ...
# 2          1192         None  -888888888          (X)        824  ...
# 3          1587         None  -888888888          (X)       1021  ...
# 4          1339         None  -888888888          (X)        703  ...
# 5          1372         None  -888888888          (X)        843  ...
# ..          ...          ...         ...          ...        ...  ...
# 892         941         None  -888888888          (X)         78  ...
# 893         935         None  -888888888          (X)        367  ...
# 894        1084         None  -888888888          (X)        405  ...
# 895        1314         None  -888888888          (X)        560  ...
# 896        1257         None  -888888888          (X)        335  ...
#
# 0   DP02_0016PM DP02_0016PMA DP02_0017E DP02_0017EA DP02_0017M DP02_0017MA  \
# 1    -888888888          (X)       3.19        None       0.20        None
# 2    -888888888          (X)       2.49        None       0.20        None
# 3    -888888888          (X)       3.21        None       0.27        None
# 4    -888888888          (X)       2.93        None       0.24        None
# 5    -888888888          (X)       3.20        None       0.25        None
# ..          ...          ...        ...         ...        ...         ...
# 892  -888888888          (X)       3.26        None       0.68        None
# 893  -888888888          (X)       2.69        None       0.24        None
# 894  -888888888          (X)       3.13        None       0.27        None
# 895  -888888888          (X)       3.35        None       0.25        None
# 896  -888888888          (X)       2.96        None       0.39        None
#
# 0   DP02_0017PE DP02_0017PEA DP02_0017PM DP02_0017PMA
# 1    -888888888          (X)  -888888888          (X)
# 2    -888888888          (X)  -888888888          (X)
# 3    -888888888          (X)  -888888888          (X)
# 4    -888888888          (X)  -888888888          (X)
# 5    -888888888          (X)  -888888888          (X)
# ..          ...          ...         ...          ...
# 892  -888888888          (X)  -888888888          (X)
# 893  -888888888          (X)  -888888888          (X)
# 894  -888888888          (X)  -888888888          (X)
# 895  -888888888          (X)  -888888888          (X)
# 896  -888888888          (X)  -888888888          (X)
#
# [896 rows x 137 columns]

# %%
# create id for every demographic in a demographic target
for demo_target_id, demo_target_df in demo_target_df_dict.items():
    demographic_id_lst = []
    for demo, demo_target in zip(demo_target_df.demographic, demo_target_df.demographic_target):
        demo_demo_target = demo_target + " " + demo
        demographic_id = hashlib.md5(demo_demo_target.encode("utf-8")).hexdigest()
        demographic_id_lst.append(demographic_id)
    demo_target_df["demographic_id"] = demographic_id_lst

# %%
demo_target_df_dict["43551e2203882bcfa813b5a1f84408c3"].head()
# Out:
#           code                                           variable  \
# 0   DP02_0001E     Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 1  DP02_0001EA  Annotation of Estimate!!HOUSEHOLDS BY TYPE!!To...
# 2   DP02_0001M  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 3  DP02_0001MA  Annotation of Margin of Error!!HOUSEHOLDS BY T...
# 4  DP02_0001PE      Percent!!HOUSEHOLDS BY TYPE!!Total households
#
#                      measurement  demographic_target       demographic  \
# 0                       estimate  households by type  total households
# 1         annotation of estimate  households by type  total households
# 2                margin of error  households by type  total households
# 3  annotation of margin of error  households by type  total households
# 4                        percent  households by type  total households
#
#               demographic_target_id                    demographic_id
# 0  43551e2203882bcfa813b5a1f84408c3  44e920fd50fbc189b315aa67243c13f8
# 1  43551e2203882bcfa813b5a1f84408c3  44e920fd50fbc189b315aa67243c13f8
# 2  43551e2203882bcfa813b5a1f84408c3  44e920fd50fbc189b315aa67243c13f8
# 3  43551e2203882bcfa813b5a1f84408c3  44e920fd50fbc189b315aa67243c13f8
# 4  43551e2203882bcfa813b5a1f84408c3  44e920fd50fbc189b315aa67243c13f8

# %%
df_variable_codes
# Out:
#               code                                           variable  \
# 0       DP02_0001E     Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 1      DP02_0001EA  Annotation of Estimate!!HOUSEHOLDS BY TYPE!!To...
# 2       DP02_0001M  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 3      DP02_0001MA  Annotation of Margin of Error!!HOUSEHOLDS BY T...
# 4      DP02_0001PE      Percent!!HOUSEHOLDS BY TYPE!!Total households
# ...            ...                                                ...
# 1227   DP02_0154MA  Annotation of Margin of Error!!COMPUTERS AND I...
# 1228   DP02_0154PE  Percent!!COMPUTERS AND INTERNET USE!!Total hou...
# 1229  DP02_0154PEA  Annotation of Percent!!COMPUTERS AND INTERNET ...
# 1230   DP02_0154PM  Percent Margin of Error!!COMPUTERS AND INTERNE...
# 1231  DP02_0154PMA  Annotation of Percent Margin of Error!!COMPUTE...
#
#                                 measurement          demographic_target  \
# 0                                  estimate          households by type
# 1                    annotation of estimate          households by type
# 2                           margin of error          households by type
# 3             annotation of margin of error          households by type
# 4                                   percent          households by type
# ...                                     ...                         ...
# 1227          annotation of margin of error  computers and internet use
# 1228                                percent  computers and internet use
# 1229                  annotation of percent  computers and internet use
# 1230                percent margin of error  computers and internet use
# 1231  annotation of percent margin of error  computers and internet use
#
#                                             demographic  \
# 0                                      total households
# 1                                      total households
# 2                                      total households
# 3                                      total households
# 4                                      total households
# ...                                                 ...
# 1227  total households with a broadband internet sub...
# 1228  total households with a broadband internet sub...
# 1229  total households with a broadband internet sub...
# 1230  total households with a broadband internet sub...
# 1231  total households with a broadband internet sub...
#
#                  demographic_target_id
# 0     43551e2203882bcfa813b5a1f84408c3
# 1     43551e2203882bcfa813b5a1f84408c3
# 2     43551e2203882bcfa813b5a1f84408c3
# 3     43551e2203882bcfa813b5a1f84408c3
# 4     43551e2203882bcfa813b5a1f84408c3
# ...                                ...
# 1227  bceb3c1f81e05c551b04247cbbf4998e
# 1228  bceb3c1f81e05c551b04247cbbf4998e
# 1229  bceb3c1f81e05c551b04247cbbf4998e
# 1230  bceb3c1f81e05c551b04247cbbf4998e
# 1231  bceb3c1f81e05c551b04247cbbf4998e
#
# [1232 rows x 6 columns]

# %%
# create reference table for variable codes

test_df = demo_target_df_dict["43551e2203882bcfa813b5a1f84408c3"].T.reset_index()

# replace header with first row
test_df.columns = test_df.iloc[0]

test_df = test_df[1:]

test_df = test_df.reset_index().rename({"code": "type"}, axis=1).drop("index", axis=1)

test_df #.columns #.reset_index()
# Out:
# 0                   type                                      DP02_0001E  \
# 0               variable  Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 1            measurement                                        estimate
# 2     demographic_target                              households by type
# 3            demographic                                total households
# 4  demographic_target_id                43551e2203882bcfa813b5a1f84408c3
# 5         demographic_id                44e920fd50fbc189b315aa67243c13f8
#
# 0                                        DP02_0001EA  \
# 0  Annotation of Estimate!!HOUSEHOLDS BY TYPE!!To...
# 1                             annotation of estimate
# 2                                 households by type
# 3                                   total households
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   44e920fd50fbc189b315aa67243c13f8
#
# 0                                         DP02_0001M  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 1                                    margin of error
# 2                                 households by type
# 3                                   total households
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   44e920fd50fbc189b315aa67243c13f8
#
# 0                                        DP02_0001MA  \
# 0  Annotation of Margin of Error!!HOUSEHOLDS BY T...
# 1                      annotation of margin of error
# 2                                 households by type
# 3                                   total households
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   44e920fd50fbc189b315aa67243c13f8
#
# 0                                    DP02_0001PE  \
# 0  Percent!!HOUSEHOLDS BY TYPE!!Total households
# 1                                        percent
# 2                             households by type
# 3                               total households
# 4               43551e2203882bcfa813b5a1f84408c3
# 5               44e920fd50fbc189b315aa67243c13f8
#
# 0                                       DP02_0001PEA  \
# 0  Annotation of Percent!!HOUSEHOLDS BY TYPE!!Tot...
# 1                              annotation of percent
# 2                                 households by type
# 3                                   total households
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   44e920fd50fbc189b315aa67243c13f8
#
# 0                                        DP02_0001PM  \
# 0  Percent Margin of Error!!HOUSEHOLDS BY TYPE!!T...
# 1                            percent margin of error
# 2                                 households by type
# 3                                   total households
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   44e920fd50fbc189b315aa67243c13f8
#
# 0                                       DP02_0001PMA  \
# 0  Annotation of Percent Margin of Error!!HOUSEHO...
# 1              annotation of percent margin of error
# 2                                 households by type
# 3                                   total households
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   44e920fd50fbc189b315aa67243c13f8
#
# 0                                         DP02_0002E  ...  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households...  ...
# 1                                           estimate  ...
# 2                                 households by type  ...
# 3          total households married-couple household  ...
# 4                   43551e2203882bcfa813b5a1f84408c3  ...
# 5                   729132cbd2d86abb56276288c1fa7689  ...
#
# 0                                        DP02_0016PM  \
# 0  Percent Margin of Error!!HOUSEHOLDS BY TYPE!!T...
# 1                            percent margin of error
# 2                                 households by type
# 3            total households average household size
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   e29605bfd8eba5a37612b7fdfb24a3a3
#
# 0                                       DP02_0016PMA  \
# 0  Annotation of Percent Margin of Error!!HOUSEHO...
# 1              annotation of percent margin of error
# 2                                 households by type
# 3            total households average household size
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   e29605bfd8eba5a37612b7fdfb24a3a3
#
# 0                                         DP02_0017E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 1                                           estimate
# 2                                 households by type
# 3               total households average family size
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   6906a5f8bdeae1618a19aa12117dca96
#
# 0                                        DP02_0017EA  \
# 0  Annotation of Estimate!!HOUSEHOLDS BY TYPE!!To...
# 1                             annotation of estimate
# 2                                 households by type
# 3               total households average family size
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   6906a5f8bdeae1618a19aa12117dca96
#
# 0                                         DP02_0017M  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 1                                    margin of error
# 2                                 households by type
# 3               total households average family size
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   6906a5f8bdeae1618a19aa12117dca96
#
# 0                                        DP02_0017MA  \
# 0  Annotation of Margin of Error!!HOUSEHOLDS BY T...
# 1                      annotation of margin of error
# 2                                 households by type
# 3               total households average family size
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   6906a5f8bdeae1618a19aa12117dca96
#
# 0                                        DP02_0017PE  \
# 0  Percent!!HOUSEHOLDS BY TYPE!!Total households!...
# 1                                            percent
# 2                                 households by type
# 3               total households average family size
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   6906a5f8bdeae1618a19aa12117dca96
#
# 0                                       DP02_0017PEA  \
# 0  Annotation of Percent!!HOUSEHOLDS BY TYPE!!Tot...
# 1                              annotation of percent
# 2                                 households by type
# 3               total households average family size
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   6906a5f8bdeae1618a19aa12117dca96
#
# 0                                        DP02_0017PM  \
# 0  Percent Margin of Error!!HOUSEHOLDS BY TYPE!!T...
# 1                            percent margin of error
# 2                                 households by type
# 3               total households average family size
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   6906a5f8bdeae1618a19aa12117dca96
#
# 0                                       DP02_0017PMA
# 0  Annotation of Percent Margin of Error!!HOUSEHO...
# 1              annotation of percent margin of error
# 2                                 households by type
# 3               total households average family size
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   6906a5f8bdeae1618a19aa12117dca96
#
# [6 rows x 137 columns]

# %%
variable_code_df = pd.concat([ demo_df for demo_df in demo_target_df_dict.values() ])

variable_code_df = variable_code_df.T.reset_index()

# replace header with first row
variable_code_df.columns = variable_code_df.iloc[0]

variable_code_df = variable_code_df[1:]

variable_code_df = variable_code_df.reset_index().rename({"code": "type"}, axis=1).drop("index", axis=1)

variable_code_df #.drop_duplicates()

# variable_code_df
# Out:
# 0                   type                                      DP02_0001E  \
# 0               variable  Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 1            measurement                                        estimate
# 2     demographic_target                              households by type
# 3            demographic                                total households
# 4  demographic_target_id                43551e2203882bcfa813b5a1f84408c3
# 5         demographic_id                44e920fd50fbc189b315aa67243c13f8
#
# 0                                        DP02_0001EA  \
# 0  Annotation of Estimate!!HOUSEHOLDS BY TYPE!!To...
# 1                             annotation of estimate
# 2                                 households by type
# 3                                   total households
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   44e920fd50fbc189b315aa67243c13f8
#
# 0                                         DP02_0001M  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 1                                    margin of error
# 2                                 households by type
# 3                                   total households
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   44e920fd50fbc189b315aa67243c13f8
#
# 0                                        DP02_0001MA  \
# 0  Annotation of Margin of Error!!HOUSEHOLDS BY T...
# 1                      annotation of margin of error
# 2                                 households by type
# 3                                   total households
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   44e920fd50fbc189b315aa67243c13f8
#
# 0                                    DP02_0001PE  \
# 0  Percent!!HOUSEHOLDS BY TYPE!!Total households
# 1                                        percent
# 2                             households by type
# 3                               total households
# 4               43551e2203882bcfa813b5a1f84408c3
# 5               44e920fd50fbc189b315aa67243c13f8
#
# 0                                       DP02_0001PEA  \
# 0  Annotation of Percent!!HOUSEHOLDS BY TYPE!!Tot...
# 1                              annotation of percent
# 2                                 households by type
# 3                                   total households
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   44e920fd50fbc189b315aa67243c13f8
#
# 0                                        DP02_0001PM  \
# 0  Percent Margin of Error!!HOUSEHOLDS BY TYPE!!T...
# 1                            percent margin of error
# 2                                 households by type
# 3                                   total households
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   44e920fd50fbc189b315aa67243c13f8
#
# 0                                       DP02_0001PMA  \
# 0  Annotation of Percent Margin of Error!!HOUSEHO...
# 1              annotation of percent margin of error
# 2                                 households by type
# 3                                   total households
# 4                   43551e2203882bcfa813b5a1f84408c3
# 5                   44e920fd50fbc189b315aa67243c13f8
#
# 0                                         DP02_0002E  ...  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households...  ...
# 1                                           estimate  ...
# 2                                 households by type  ...
# 3          total households married-couple household  ...
# 4                   43551e2203882bcfa813b5a1f84408c3  ...
# 5                   729132cbd2d86abb56276288c1fa7689  ...
#
# 0                                        DP02_0153PM  \
# 0  Percent Margin of Error!!COMPUTERS AND INTERNE...
# 1                            percent margin of error
# 2                         computers and internet use
# 3                   total households with a computer
# 4                   bceb3c1f81e05c551b04247cbbf4998e
# 5                   76e578c8c1b6f25ae4b11331c19834ab
#
# 0                                       DP02_0153PMA  \
# 0  Annotation of Percent Margin of Error!!COMPUTE...
# 1              annotation of percent margin of error
# 2                         computers and internet use
# 3                   total households with a computer
# 4                   bceb3c1f81e05c551b04247cbbf4998e
# 5                   76e578c8c1b6f25ae4b11331c19834ab
#
# 0                                         DP02_0154E  \
# 0  Estimate!!COMPUTERS AND INTERNET USE!!Total ho...
# 1                                           estimate
# 2                         computers and internet use
# 3  total households with a broadband internet sub...
# 4                   bceb3c1f81e05c551b04247cbbf4998e
# 5                   2c8ba9d62282dd5f4a52a3e39244e6b6
#
# 0                                        DP02_0154EA  \
# 0  Annotation of Estimate!!COMPUTERS AND INTERNET...
# 1                             annotation of estimate
# 2                         computers and internet use
# 3  total households with a broadband internet sub...
# 4                   bceb3c1f81e05c551b04247cbbf4998e
# 5                   2c8ba9d62282dd5f4a52a3e39244e6b6
#
# 0                                         DP02_0154M  \
# 0  Margin of Error!!COMPUTERS AND INTERNET USE!!T...
# 1                                    margin of error
# 2                         computers and internet use
# 3  total households with a broadband internet sub...
# 4                   bceb3c1f81e05c551b04247cbbf4998e
# 5                   2c8ba9d62282dd5f4a52a3e39244e6b6
#
# 0                                        DP02_0154MA  \
# 0  Annotation of Margin of Error!!COMPUTERS AND I...
# 1                      annotation of margin of error
# 2                         computers and internet use
# 3  total households with a broadband internet sub...
# 4                   bceb3c1f81e05c551b04247cbbf4998e
# 5                   2c8ba9d62282dd5f4a52a3e39244e6b6
#
# 0                                        DP02_0154PE  \
# 0  Percent!!COMPUTERS AND INTERNET USE!!Total hou...
# 1                                            percent
# 2                         computers and internet use
# 3  total households with a broadband internet sub...
# 4                   bceb3c1f81e05c551b04247cbbf4998e
# 5                   2c8ba9d62282dd5f4a52a3e39244e6b6
#
# 0                                       DP02_0154PEA  \
# 0  Annotation of Percent!!COMPUTERS AND INTERNET ...
# 1                              annotation of percent
# 2                         computers and internet use
# 3  total households with a broadband internet sub...
# 4                   bceb3c1f81e05c551b04247cbbf4998e
# 5                   2c8ba9d62282dd5f4a52a3e39244e6b6
#
# 0                                        DP02_0154PM  \
# 0  Percent Margin of Error!!COMPUTERS AND INTERNE...
# 1                            percent margin of error
# 2                         computers and internet use
# 3  total households with a broadband internet sub...
# 4                   bceb3c1f81e05c551b04247cbbf4998e
# 5                   2c8ba9d62282dd5f4a52a3e39244e6b6
#
# 0                                       DP02_0154PMA
# 0  Annotation of Percent Margin of Error!!COMPUTE...
# 1              annotation of percent margin of error
# 2                         computers and internet use
# 3  total households with a broadband internet sub...
# 4                   bceb3c1f81e05c551b04247cbbf4998e
# 5                   2c8ba9d62282dd5f4a52a3e39244e6b6
#
# [6 rows x 1233 columns]

# %%
demo_target_geo_df_dict["43551e2203882bcfa813b5a1f84408c3"].head()
# Out:
# 0                GEO_ID DP02_0001E DP02_0001EA DP02_0001M DP02_0001MA  \
# 1  1400000US19155031601       1891        None        160        None
# 2  1400000US19155031602       1192        None        197        None
# 3  1400000US19155031700       1587        None        161        None
# 4  1400000US19155031800       1339        None        149        None
# 5  1400000US19155031900       1372        None        117        None
#
# 0 DP02_0001PE DP02_0001PEA DP02_0001PM DP02_0001PMA DP02_0002E  ...  \
# 1        1891         None  -888888888          (X)       1232  ...
# 2        1192         None  -888888888          (X)        824  ...
# 3        1587         None  -888888888          (X)       1021  ...
# 4        1339         None  -888888888          (X)        703  ...
# 5        1372         None  -888888888          (X)        843  ...
#
# 0 DP02_0016PM DP02_0016PMA DP02_0017E DP02_0017EA DP02_0017M DP02_0017MA  \
# 1  -888888888          (X)       3.19        None       0.20        None
# 2  -888888888          (X)       2.49        None       0.20        None
# 3  -888888888          (X)       3.21        None       0.27        None
# 4  -888888888          (X)       2.93        None       0.24        None
# 5  -888888888          (X)       3.20        None       0.25        None
#
# 0 DP02_0017PE DP02_0017PEA DP02_0017PM DP02_0017PMA
# 1  -888888888          (X)  -888888888          (X)
# 2  -888888888          (X)  -888888888          (X)
# 3  -888888888          (X)  -888888888          (X)
# 4  -888888888          (X)  -888888888          (X)
# 5  -888888888          (X)  -888888888          (X)
#
# [5 rows x 137 columns]

# %%
df_census_test = df_census[["GEO_ID", "DP02_0001E"]]

df_census_test
# Out:
# 0                  GEO_ID DP02_0001E
# 1    1400000US19155031601       1891
# 2    1400000US19155031602       1192
# 3    1400000US19155031700       1587
# 4    1400000US19155031800       1339
# 5    1400000US19155031900       1372
# ..                    ...        ...
# 892  1400000US19155030900        941
# 893  1400000US19155031000        935
# 894  1400000US19155031100       1084
# 895  1400000US19155031200       1314
# 896  1400000US19155031300       1257
#
# [896 rows x 2 columns]

# %%
print("demo_target:", len(df_variable_codes.demographic_target.unique()))
print("demo:", len(df_variable_codes.demographic.unique()))
# Out:
# demo_target: 17
# demo: 152

# %%
df_variable_codes[df_variable_codes["demographic_target"] == "households by type"]
# Out:
# array(['total households', 'total households married-couple household',
#        'total households married-couple household with children of the householder under 18 years',
#        'total households cohabiting couple household',
#        'total households cohabiting couple household with children of the householder under 18 years',
#        'total households male householder, no spouse/partner present',
#        'total households male householder, no spouse/partner present with children of the householder under 18 years',
#        'total households male householder, no spouse/partner present householder living alone',
#        'total households male householder, no spouse/partner present householder living alone 65 years and over',
#        'total households female householder, no spouse/partner present',
#        'total households female householder, no spouse/partner present with children of the householder under 18 years',
#        'total households female householder, no spouse/partner present householder living alone',
#        'total households female householder, no spouse/partner present householder living alone 65 years and over',
#        'total households households with one or more people under 18 years',
#        'total households households with one or more people 65 years and over',
#        'total households average household size',
#        'total households average family size'], dtype=object)

# %%
## create measurement df
# for every code: capture the measurement, demo target & demographic

measurement = set()
demographic_target = set()
demographic = set()

for i, col in zip(df_census.iloc[:, :-5].index, df_census.columns[:-5]):
    col_split = col.split("!!")
    if len(col_split) == 0:
        continue

    col_measure = col_split[0]

    measurement.add(col_measure.lower()) # measurement value
    demographic_target.add(col_split[1].lower()) # demographic target
    
    if len(col_split[2:]) > 1:
        demographic.add(" ".join(map(str, col_split[2:])).lower()) # demographic
    else: 
        demographic.add(col_split[2].lower()) # demographic

# %%
# replace header with first row
df_census.columns = df_census.iloc[0]

df_census = df_census[1:]

# re order headers
df_census = df_census[ df_census.columns.tolist()[-5:] + df_census.columns.tolist()[:-5] ]

# %%
# create categories from column names
category_dict = {"measurement":[], "profile":[], "population":[], "type":[]}

# split columns names on "!!"
# measurement = 
# profile = 
# population =
# type =

# iterate through columns created from a variable code
for c in df_new.columns[:-5]:
    col_split = c.split("!!")
    category_dict["measurement"].append(col_split[0])
    category_dict["profile"].append(col_split[1])
    category_dict["population"].append(col_split[2])
    # category_dict["type"].append(" ".join(col_split[3:]))
    type_val = col_split[3:]
    if len(type_val) == 0:
        category_dict["type"].append(["Total"])
    else:
        category_dict["type"].append(col_split[3:])

# %%
# create unique IDs
def unique_id(dict, dict_k):
    col_dict = {}
    i = 1
    for val in set(dict[dict_k]):
        col_dict[i] = val
        i+=1
    return col_dict

# %%
measurement_dict = unique_id(category_dict, "measurement")
profile_dict = unique_id(category_dict, "profile")

# %%
# profile_dict

# %%
type_dict = {}
i = 1
for x in category_dict["type"]:
    if x in list(type_dict.values()):
        continue
    elif x == "total":
        type_dict[i] = x
        i+=1
    elif x[0] in type_dict.values():
        continue
    else:
       type_dict[i] = x[0]
       i+=1

# type_dict

# %%
# iterate through columns
# parse column names
# pair column to each dictionary based on values

### add this to the above loop under "# create categories from column names"

# %%
# find key from value
def get_key(var_dict, val):
    for k, v in var_dict.items():
        if v == val:
            return k
